# %% [markdown]
# <a href="https://colab.research.google.com/github/dikshanaa-m/Extract-Text-from-a-Website/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.google.com"
soup = BeautifulSoup(requests.get(url).text, 'html.parser')
print(f"Page Title: {soup.title.string}")
# Out:
# Page Title: Google
